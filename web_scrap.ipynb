# %%
from bs4 import BeautifulSoup
import requests
import time
import datetime

import smtplib
import pandas as pd

# %%
#code to extract all tables from the website
import pandas as pd
url="https://en.wikipedia.org/wiki/Bloody_Sunday_(1905)"
x=pd.read_html(url)

# %%
data=pd.DataFrame()
def ectract_data(art):
    books=[]
    stars=[]
    prices=[]
    ol=soup.find('ol')
    articles=ol.find_all('article',class_='product_pod')
    for article in articles:
        image=article.find('img')
        title=image.attrs['alt'] #attrs gets the attributes in the img tag
        # print(title)
        books.append(title)
        star=article.find('p')
        # print(star)
        star=star['class'][1]
        stars.append(star)
        # print(star)
        price=article.find('p',class_='price_color').text  
        price=float(price[1:])
        # print(price)
        prices.append(price)
    return(books,stars,prices)
for i in range(1,51):
    url=f'https://books.toscrape.com/catalogue/page-{i}.html'
    print(url)
    response=requests.get(url)
    response=response.content
    soup=BeautifulSoup(response,'html.parser')
    book,star,price=ectract_data(soup)
    d1_dic={'Books':book,'Stars':star,'Prices':price}
    d1=pd.DataFrame(data=d1_dic)
    data=pd.concat([data,d1],ignore_index=True)
# Out:
# https://books.toscrape.com/catalogue/page-1.html
# https://books.toscrape.com/catalogue/page-2.html
# https://books.toscrape.com/catalogue/page-3.html
# https://books.toscrape.com/catalogue/page-4.html
# https://books.toscrape.com/catalogue/page-5.html
# https://books.toscrape.com/catalogue/page-6.html
# https://books.toscrape.com/catalogue/page-7.html
# https://books.toscrape.com/catalogue/page-8.html
# https://books.toscrape.com/catalogue/page-9.html
# https://books.toscrape.com/catalogue/page-10.html
# https://books.toscrape.com/catalogue/page-11.html
# https://books.toscrape.com/catalogue/page-12.html
# https://books.toscrape.com/catalogue/page-13.html
# https://books.toscrape.com/catalogue/page-14.html
# https://books.toscrape.com/catalogue/page-15.html
# https://books.toscrape.com/catalogue/page-16.html
# https://books.toscrape.com/catalogue/page-17.html
# https://books.toscrape.com/catalogue/page-18.html
# https://books.toscrape.com/catalogue/page-19.html
# ...

# %%
data
# Out:
#                                                  Books  Stars  Prices
# 0                                 A Light in the Attic  Three   51.77
# 1                                   Tipping the Velvet    One   53.74
# 2                                           Soumission    One   50.10
# 3                                        Sharp Objects   Four   47.82
# 4                Sapiens: A Brief History of Humankind   Five   54.23
# ..                                                 ...    ...     ...
# 995  Alice in Wonderland (Alice's Adventures in Won...    One   55.53
# 996   Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)   Four   57.06
# 997  A Spy's Devotion (The Regency Spies of London #1)   Five   16.97
# 998                1st to Die (Women's Murder Club #1)    One   53.98
# 999                 1,000 Places to See Before You Die   Five   26.08
#
# [1000 rows x 3 columns]
